# %%
'''
# Using pip
$ pip install plotnine         # 1. should be sufficient for most
$ pip install 'plotnine[all]'  # 2. includes extra/optional packages
'''

# %%
from plotnine import *
from plotnine.data import mtcars
# Out:
# C:\Users\Roja Achary\Anaconda3\envs\lab\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# C:\Users\Roja Achary\Anaconda3\envs\lab\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# C:\Users\Roja Achary\Anaconda3\envs\lab\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# C:\Users\Roja Achary\Anaconda3\envs\lab\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
#Scatter plot

# %%
(ggplot(mtcars, aes('wt', 'mpg'))
 + geom_point())
# Out:
# <ggplot: (121733928091)>

# %%
#Scatter plot colored according some variable

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point())
# Out:
# <ggplot: (121734721470)>

# %%
#Scatter plot colored according some variable and smoothed with a linear model with confidence intervals.

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm'))
# Out:
# <ggplot: (-9223371915120600653)>

# %%
#Scatter plot colored according some variable, 
#smoothed with a linear model with confidence intervals and plotted on separate panels.

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~gear'))
# Out:
# <ggplot: (121602975706)>

# %%
#Make it playful

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~gear')
 + theme_xkcd())
# Out:
# <ggplot: (-9223371915251603105)>
