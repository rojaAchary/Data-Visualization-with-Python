# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

# %%
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
Z
# Out:
# array([[-0.83907153, -0.83470697, -0.8216586 , ...,  0.8956708 ,
#          0.68617261,  0.41940746],
#        [-0.83907153, -0.8275558 , -0.80744041, ...,  0.93467448,
#          0.77467433,  0.55894214],
#        [-0.83907153, -0.820263  , -0.79266951, ...,  0.98503397,
#          0.88847607,  0.73757604],
#        ...,
#        [-0.83907153, -0.48696962, -0.02692065, ...,  0.98525345,
#          0.79584263,  0.46799565],
#        [-0.83907153, -0.47558005, -0.00130271, ...,  0.93488414,
#          0.6993547 ,  0.37933079],
#        [-0.83907153, -0.46410908,  0.02431613, ...,  0.89579384,
#          0.65690314,  0.40107702]])

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7051825e770b> in <module>
#       1 plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
#       2 plt.colorbar()
# ----> 3 plt.axis(aspect='image');
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\pyplot.py in axis(emit, *args, **kwargs)
#    2459 @_copy_docstring_and_deprecators(Axes.axis)
#    2460 def axis(*args, emit=True, **kwargs):
# -> 2461     return gca().axis(*args, emit=emit, **kwargs)
#    2462
#    2463
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\axes\_base.py in axis(self, emit, *args, **kwargs)
#    1811             self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    1812         if kwargs:
# -> 1813             raise TypeError(f"axis() got an unexpected keyword argument "
#    1814                             f"'{next(iter(kwargs))}'")
#    1815         return (*self.get_xlim(), *self.get_ylim())
#
# TypeError: axis() got an unexpected keyword argument 'aspect'

# %%
plt.figure(figsize=(30,15))
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=10)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar();
